# %%
import df_eda
# %matplotlib inline

# %% [markdown]
# ### 데이터 적용

# %%
df = pd.read_csv('BankChurners_chng.csv')

# %%
df.head(3)
# Out:
#    CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0  768805383  Existing Customer            45      M                3
# 1  818770008  Existing Customer            49      F                5
# 2  713982108  Existing Customer            51      M                3
#
#   Education_Level Marital_Status Income_Category Card_Category  \
# 0     High School        Married     $60K - $80K          Blue
# 1        Graduate         Single  Less than $40K          Blue
# 2        Graduate        Married    $80K - $120K          Blue
#
#    Months_on_book  ...  Months_Inactive_12_mon  Contacts_Count_12_mon  \
# 0              39  ...                       1                      3
# 1              44  ...                       1                      2
# 2              36  ...                       1                      0
#
#    Credit_Limit  Total_Revolving_Bal  Avg_Open_To_Buy  Total_Amt_Chng_Q4_Q1  \
# ...

# %%
func = df_eda.df_eda()

# %%
func.df_describe(df, 'CLIENTNUM', t_object=True )
# Out:
#             column  label_count         Top1_label  Top1_percent  \
# 0   Attrition_Flag            2  Existing Customer          0.84
# 1           Gender            2                  F          0.53
# 2  Education_Level            7           Graduate          0.31
# 3   Marital_Status            4            Married          0.46
# 4  Income_Category            6     Less than $40K          0.35
# 5    Card_Category            4               Blue          0.93
#
#           Top2_label  Top2_percent
# 0  Attrited Customer          0.16
# 1                  M          0.47
# 2        High School          0.20
# 3             Single          0.39
# 4        $40K - $60K          0.18
# 5             Silver          0.05

# %%
func.df_describe(df, 'CLIENTNUM', t_object=False )
# Out:
#                        index    count         mean         std          min  \
# 0                  CLIENTNUM 10127.00 739177606.33 36903783.45 708082083.00
# 1               Customer_Age 10127.00        46.33        8.02        26.00
# 2            Dependent_count 10127.00         2.35        1.30         0.00
# 3             Months_on_book 10127.00        35.93        7.99        13.00
# 4   Total_Relationship_Count 10127.00         3.81        1.55         1.00
# 5     Months_Inactive_12_mon 10127.00         2.34        1.01         0.00
# 6      Contacts_Count_12_mon 10127.00         2.46        1.11         0.00
# 7               Credit_Limit 10127.00      8631.95     9088.78      1438.30
# 8        Total_Revolving_Bal 10127.00      1162.81      814.99         0.00
# 9            Avg_Open_To_Buy 10127.00      7469.14     9090.69         3.00
# 10      Total_Amt_Chng_Q4_Q1 10127.00         0.76        0.22         0.00
# ...

# %%
func.df_graph(df, t_object=True)
# Out:
# #########Attrition_Flag##########
# Unique value : 2, Missing value : 0
# #########Gender##########
# Unique value : 2, Missing value : 0
# #########Education_Level##########
# Unique value : 7, Missing value : 0
# #########Marital_Status##########
# Unique value : 4, Missing value : 0
# #########Income_Category##########
# Unique value : 6, Missing value : 0
# #########Card_Category##########
# Unique value : 4, Missing value : 0
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-275-6b0f5cc62c67> in <module>
# ----> 1 func.df_graph(df, t_object=True)
#
# ~\Desktop\python\Functions\1. Feature engineering\df_eda.py in df_graph(self, df, t_object)
#     120
#     121         index = ['missing_count', 'missing_percent', 'skewness', 'kurtosis', 'outlier_count', 'outlier_percent']
# --> 122         summ_df.index = index
#     123
# ...

# %%
func.df_graph(df, t_object=False)
# Out:
# Summary Data :
# <style  type="text/css" >
# ...
